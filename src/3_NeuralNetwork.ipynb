# %% [markdown]
# # Deep Learning Neural Network

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
from numpy.random import seed
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import tensorflow
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

seed(6162)

# %% [markdown]
# ## Read the data

# %%
#Load the dataset
song_data = pd.read_csv('https://raw.githubusercontent.com/yashapatel131/KDD_GroupProject/main/Datasets/Song_Attributes.csv')
song_data.head()
# Out:
#    ID  Acousticness                             Album           Artist  \
# 0   0      0.000728  Collective Soul (Deluxe Version)  Collective Soul
# 1   1      0.018200  Collective Soul (Deluxe Version)  Collective Soul
# 2   2      0.000473  Collective Soul (Deluxe Version)  Collective Soul
# 3   3      0.000970  Collective Soul (Deluxe Version)  Collective Soul
# 4   4      0.000036  Collective Soul (Deluxe Version)  Collective Soul
#
#    Danceability  Duration  Energy  Explicit  Instrumentalness  Liveness  \
# 0         0.520    234947   0.904     False          0.010300    0.0634
# 1         0.581    239573   0.709     False          0.000664    0.1740
# 2         0.572    198400   0.918     False          0.000431    0.0977
# 3         0.596    231453   0.661     False          0.000033    0.1130
# 4         0.520    222520   0.808     False          0.000010    0.0800
#
#    Loudness  Mode               Name  Popularity popularityLabel  Speechiness  \
# 0    -5.030     1  Welcome All Again          35         Popular       0.0309
# 1    -4.909     1              Fuzzy          31         Popular       0.0282
# 2    -3.324     0                Dig          30         Popular       0.0559
# 3    -5.051     1                You          35         Popular       0.0254
# 4    -4.553     0            My Days          21         Popular       0.0318
#
#      Tempo  TimeSignature  Valence
# 0  106.022              4    0.365
# 1  120.027              4    0.408
# 2  144.061              4    0.370
# 3  111.975              4    0.183
# 4   92.721              4    0.666

# %%
#Drop some columns
songAttributes = song_data.drop(columns=['ID', 'Album', 'Mode', 'Name'])
songAttributes.head()
# Out:
#    Acousticness           Artist  Danceability  Duration  Energy  Explicit  \
# 0      0.000728  Collective Soul         0.520    234947   0.904     False
# 1      0.018200  Collective Soul         0.581    239573   0.709     False
# 2      0.000473  Collective Soul         0.572    198400   0.918     False
# 3      0.000970  Collective Soul         0.596    231453   0.661     False
# 4      0.000036  Collective Soul         0.520    222520   0.808     False
#
#    Instrumentalness  Liveness  Loudness  Popularity popularityLabel  \
# 0          0.010300    0.0634    -5.030          35         Popular
# 1          0.000664    0.1740    -4.909          31         Popular
# 2          0.000431    0.0977    -3.324          30         Popular
# 3          0.000033    0.1130    -5.051          35         Popular
# 4          0.000010    0.0800    -4.553          21         Popular
#
#    Speechiness    Tempo  TimeSignature  Valence
# 0       0.0309  106.022              4    0.365
# 1       0.0282  120.027              4    0.408
# 2       0.0559  144.061              4    0.370
# 3       0.0254  111.975              4    0.183
# 4       0.0318   92.721              4    0.666

# %%
#Dummy encoding and view the new columns
songAttributes_binary_encoded = pd.get_dummies(songAttributes, columns=['Artist', 'TimeSignature', 'Explicit'])
songAttributes_binary_encoded.columns
# Out:
# Index(['Acousticness', 'Danceability', 'Duration', 'Energy',
#        'Instrumentalness', 'Liveness', 'Loudness', 'Popularity',
#        'popularityLabel', 'Speechiness',
#        ...
#        'Artist_t.A.T.u.', 'Artist_twenty one pilots', 'Artist_will.i.am',
#        'TimeSignature_0', 'TimeSignature_1', 'TimeSignature_3',
#        'TimeSignature_4', 'TimeSignature_5', 'Explicit_False',
#        'Explicit_True'],
#       dtype='object', length=1007)

# %% [markdown]
# ## Splitting the data

# %%
X = songAttributes_binary_encoded.drop(['popularityLabel', 'Popularity', 'Artist_t.A.T.u.', 'TimeSignature_1', 'Explicit_False'], axis=1)
y = songAttributes_binary_encoded['popularityLabel']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 6162)
X_train.head()
# Out:
#         Acousticness  Danceability  Duration  Energy  Instrumentalness  \
# 48090        0.11800         0.608    289173   0.312          0.000029
# 30590        0.01210         0.381    490960   0.965          0.021800
# 36643        0.10500         0.532    228587   0.466          0.000077
# 137260       0.00304         0.582    567346   0.961          0.807000
# 147494       0.37100         0.855    324189   0.694          0.000000
#
#         Liveness  Loudness  Speechiness    Tempo  Valence  ...  Artist_iio  \
# 48090     0.1030    -8.711       0.0263   93.034    0.223  ...           0
# 30590     0.9660    -3.676       0.1250  136.505    0.328  ...           0
# 36643     0.0737    -6.412       0.0279  159.956    0.430  ...           0
# 137260    0.0859   -10.149       0.0381  135.995    0.828  ...           0
# 147494    0.1090    -4.393       0.1690  122.078    0.490  ...           0
#
#         Artist_k.d. lang  Artist_matchbox twenty  Artist_twenty one pilots  \
# 48090                  0                       0                         0
# 30590                  0                       0                         0
# 36643                  0                       0                         0
# 137260                 0                       0                         0
# 147494                 0                       0                         0
#
#         Artist_will.i.am  TimeSignature_0  TimeSignature_3  TimeSignature_4  \
# 48090                  0                0                1                0
# 30590                  0                0                0                1
# 36643                  0                0                1                0
# 137260                 0                0                0                1
# 147494                 0                0                0                1
#
#         TimeSignature_5  Explicit_True
# 48090                 0              0
# 30590                 0              0
# 36643                 0              0
# 137260                0              0
# 147494                0              1
#
# [5 rows x 1002 columns]

# %% [markdown]
# ## Transform the data

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# ## Create the model

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=1002))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               100300
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 110,602
# Trainable params: 110,602
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit the model

# %%
model.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 3390/3390 - 3s - loss: 0.5147 - accuracy: 0.7415 - 3s/epoch - 767us/step
# Epoch 2/100
# 3390/3390 - 2s - loss: 0.4805 - accuracy: 0.7622 - 2s/epoch - 656us/step
# Epoch 3/100
# 3390/3390 - 2s - loss: 0.4683 - accuracy: 0.7707 - 2s/epoch - 649us/step
# Epoch 4/100
# 3390/3390 - 2s - loss: 0.4590 - accuracy: 0.7751 - 2s/epoch - 655us/step
# Epoch 5/100
# 3390/3390 - 2s - loss: 0.4515 - accuracy: 0.7792 - 2s/epoch - 669us/step
# Epoch 6/100
# 3390/3390 - 2s - loss: 0.4456 - accuracy: 0.7836 - 2s/epoch - 709us/step
# Epoch 7/100
# 3390/3390 - 2s - loss: 0.4397 - accuracy: 0.7867 - 2s/epoch - 675us/step
# Epoch 8/100
# 3390/3390 - 2s - loss: 0.4341 - accuracy: 0.7891 - 2s/epoch - 734us/step
# Epoch 9/100
# 3390/3390 - 3s - loss: 0.4290 - accuracy: 0.7916 - 3s/epoch - 818us/step
# Epoch 10/100
# 3390/3390 - 3s - loss: 0.4239 - accuracy: 0.7951 - 3s/epoch - 752us/step
# Epoch 11/100
# 3390/3390 - 3s - loss: 0.4186 - accuracy: 0.7968 - 3s/epoch - 768us/step
# Epoch 12/100
# 3390/3390 - 3s - loss: 0.4137 - accuracy: 0.7999 - 3s/epoch - 771us/step
# Epoch 13/100
# 3390/3390 - 3s - loss: 0.4089 - accuracy: 0.8019 - 3s/epoch - 759us/step
# Epoch 14/100
# 3390/3390 - 3s - loss: 0.4043 - accuracy: 0.8039 - 3s/epoch - 795us/step
# Epoch 15/100
# 3390/3390 - 3s - loss: 0.3995 - accuracy: 0.8061 - 3s/epoch - 741us/step
# Epoch 16/100
# 3390/3390 - 2s - loss: 0.3947 - accuracy: 0.8080 - 2s/epoch - 731us/step
# Epoch 17/100
# 3390/3390 - 2s - loss: 0.3906 - accuracy: 0.8106 - 2s/epoch - 734us/step
# Epoch 18/100
# 3390/3390 - 2s - loss: 0.3857 - accuracy: 0.8128 - 2s/epoch - 734us/step
# Epoch 19/100
# 3390/3390 - 2s - loss: 0.3815 - accuracy: 0.8154 - 2s/epoch - 734us/step
# Epoch 20/100
# 3390/3390 - 3s - loss: 0.3773 - accuracy: 0.8179 - 3s/epoch - 738us/step
# Epoch 21/100
# 3390/3390 - 2s - loss: 0.3723 - accuracy: 0.8202 - 2s/epoch - 734us/step
# Epoch 22/100
# 3390/3390 - 3s - loss: 0.3680 - accuracy: 0.8227 - 3s/epoch - 738us/step
# Epoch 23/100
# 3390/3390 - 2s - loss: 0.3643 - accuracy: 0.8248 - 2s/epoch - 726us/step
# Epoch 24/100
# 3390/3390 - 3s - loss: 0.3602 - accuracy: 0.8270 - 3s/epoch - 752us/step
# Epoch 25/100
# 3390/3390 - 3s - loss: 0.3563 - accuracy: 0.8292 - 3s/epoch - 764us/step
# Epoch 26/100
# 3390/3390 - 3s - loss: 0.3522 - accuracy: 0.8317 - 3s/epoch - 758us/step
# Epoch 27/100
# 3390/3390 - 2s - loss: 0.3495 - accuracy: 0.8323 - 2s/epoch - 732us/step
# Epoch 28/100
# 3390/3390 - 2s - loss: 0.3455 - accuracy: 0.8346 - 2s/epoch - 734us/step
# Epoch 29/100
# 3390/3390 - 2s - loss: 0.3418 - accuracy: 0.8376 - 2s/epoch - 721us/step
# Epoch 30/100
# 3390/3390 - 2s - loss: 0.3382 - accuracy: 0.8384 - 2s/epoch - 715us/step
# Epoch 31/100
# 3390/3390 - 2s - loss: 0.3354 - accuracy: 0.8400 - 2s/epoch - 718us/step
# Epoch 32/100
# 3390/3390 - 2s - loss: 0.3321 - accuracy: 0.8419 - 2s/epoch - 718us/step
# Epoch 33/100
# 3390/3390 - 2s - loss: 0.3295 - accuracy: 0.8426 - 2s/epoch - 729us/step
# Epoch 34/100
# 3390/3390 - 3s - loss: 0.3256 - accuracy: 0.8453 - 3s/epoch - 750us/step
# Epoch 35/100
# 3390/3390 - 3s - loss: 0.3229 - accuracy: 0.8455 - 3s/epoch - 793us/step
# Epoch 36/100
# 3390/3390 - 3s - loss: 0.3201 - accuracy: 0.8486 - 3s/epoch - 751us/step
# Epoch 37/100
# 3390/3390 - 3s - loss: 0.3174 - accuracy: 0.8501 - 3s/epoch - 746us/step
# Epoch 38/100
# 3390/3390 - 2s - loss: 0.3148 - accuracy: 0.8503 - 2s/epoch - 737us/step
# Epoch 39/100
# 3390/3390 - 3s - loss: 0.3120 - accuracy: 0.8522 - 3s/epoch - 740us/step
# Epoch 40/100
# 3390/3390 - 3s - loss: 0.3096 - accuracy: 0.8528 - 3s/epoch - 739us/step
# Epoch 41/100
# 3390/3390 - 2s - loss: 0.3077 - accuracy: 0.8541 - 2s/epoch - 732us/step
# Epoch 42/100
# 3390/3390 - 3s - loss: 0.3056 - accuracy: 0.8555 - 3s/epoch - 758us/step
# Epoch 43/100
# 3390/3390 - 3s - loss: 0.3029 - accuracy: 0.8581 - 3s/epoch - 749us/step
# Epoch 44/100
# 3390/3390 - 3s - loss: 0.3003 - accuracy: 0.8575 - 3s/epoch - 754us/step
# Epoch 45/100
# 3390/3390 - 3s - loss: 0.2981 - accuracy: 0.8595 - 3s/epoch - 751us/step
# Epoch 46/100
# 3390/3390 - 2s - loss: 0.2960 - accuracy: 0.8599 - 2s/epoch - 727us/step
# Epoch 47/100
# 3390/3390 - 3s - loss: 0.2942 - accuracy: 0.8614 - 3s/epoch - 751us/step
# Epoch 48/100
# 3390/3390 - 3s - loss: 0.2930 - accuracy: 0.8630 - 3s/epoch - 776us/step
# Epoch 49/100
# 3390/3390 - 2s - loss: 0.2899 - accuracy: 0.8633 - 2s/epoch - 735us/step
# Epoch 50/100
# 3390/3390 - 3s - loss: 0.2891 - accuracy: 0.8642 - 3s/epoch - 738us/step
# Epoch 51/100
# 3390/3390 - 2s - loss: 0.2867 - accuracy: 0.8651 - 2s/epoch - 728us/step
# Epoch 52/100
# 3390/3390 - 3s - loss: 0.2846 - accuracy: 0.8658 - 3s/epoch - 741us/step
# Epoch 53/100
# 3390/3390 - 3s - loss: 0.2835 - accuracy: 0.8670 - 3s/epoch - 747us/step
# Epoch 54/100
# 3390/3390 - 3s - loss: 0.2817 - accuracy: 0.8674 - 3s/epoch - 746us/step
# Epoch 55/100
# 3390/3390 - 3s - loss: 0.2799 - accuracy: 0.8684 - 3s/epoch - 744us/step
# Epoch 56/100
# 3390/3390 - 3s - loss: 0.2778 - accuracy: 0.8694 - 3s/epoch - 777us/step
# Epoch 57/100
# 3390/3390 - 3s - loss: 0.2769 - accuracy: 0.8698 - 3s/epoch - 743us/step
# Epoch 58/100
# 3390/3390 - 2s - loss: 0.2754 - accuracy: 0.8705 - 2s/epoch - 731us/step
# Epoch 59/100
# 3390/3390 - 3s - loss: 0.2740 - accuracy: 0.8716 - 3s/epoch - 744us/step
# Epoch 60/100
# 3390/3390 - 2s - loss: 0.2724 - accuracy: 0.8719 - 2s/epoch - 733us/step
# Epoch 61/100
# 3390/3390 - 3s - loss: 0.2712 - accuracy: 0.8733 - 3s/epoch - 744us/step
# Epoch 62/100
# 3390/3390 - 3s - loss: 0.2698 - accuracy: 0.8739 - 3s/epoch - 747us/step
# Epoch 63/100
# 3390/3390 - 3s - loss: 0.2672 - accuracy: 0.8749 - 3s/epoch - 739us/step
# Epoch 64/100
# 3390/3390 - 3s - loss: 0.2672 - accuracy: 0.8752 - 3s/epoch - 748us/step
# Epoch 65/100
# 3390/3390 - 2s - loss: 0.2648 - accuracy: 0.8758 - 2s/epoch - 719us/step
# Epoch 66/100
# 3390/3390 - 2s - loss: 0.2640 - accuracy: 0.8771 - 2s/epoch - 736us/step
# Epoch 67/100
# 3390/3390 - 2s - loss: 0.2624 - accuracy: 0.8774 - 2s/epoch - 731us/step
# Epoch 68/100
# 3390/3390 - 2s - loss: 0.2614 - accuracy: 0.8776 - 2s/epoch - 737us/step
# Epoch 69/100
# 3390/3390 - 2s - loss: 0.2597 - accuracy: 0.8791 - 2s/epoch - 724us/step
# Epoch 70/100
# 3390/3390 - 2s - loss: 0.2588 - accuracy: 0.8801 - 2s/epoch - 733us/step
# Epoch 71/100
# 3390/3390 - 2s - loss: 0.2585 - accuracy: 0.8795 - 2s/epoch - 728us/step
# Epoch 72/100
# 3390/3390 - 2s - loss: 0.2563 - accuracy: 0.8806 - 2s/epoch - 726us/step
# Epoch 73/100
# 3390/3390 - 2s - loss: 0.2555 - accuracy: 0.8806 - 2s/epoch - 726us/step
# Epoch 74/100
# 3390/3390 - 2s - loss: 0.2541 - accuracy: 0.8820 - 2s/epoch - 721us/step
# Epoch 75/100
# 3390/3390 - 2s - loss: 0.2536 - accuracy: 0.8820 - 2s/epoch - 725us/step
# Epoch 76/100
# 3390/3390 - 3s - loss: 0.2524 - accuracy: 0.8836 - 3s/epoch - 767us/step
# Epoch 77/100
# 3390/3390 - 2s - loss: 0.2505 - accuracy: 0.8831 - 2s/epoch - 737us/step
# Epoch 78/100
# 3390/3390 - 2s - loss: 0.2509 - accuracy: 0.8832 - 2s/epoch - 735us/step
# Epoch 79/100
# 3390/3390 - 3s - loss: 0.2497 - accuracy: 0.8833 - 3s/epoch - 740us/step
# Epoch 80/100
# 3390/3390 - 2s - loss: 0.2488 - accuracy: 0.8852 - 2s/epoch - 670us/step
# Epoch 81/100
# 3390/3390 - 2s - loss: 0.2480 - accuracy: 0.8850 - 2s/epoch - 683us/step
# Epoch 82/100
# 3390/3390 - 2s - loss: 0.2467 - accuracy: 0.8864 - 2s/epoch - 677us/step
# Epoch 83/100
# 3390/3390 - 2s - loss: 0.2455 - accuracy: 0.8866 - 2s/epoch - 673us/step
# Epoch 84/100
# 3390/3390 - 2s - loss: 0.2451 - accuracy: 0.8865 - 2s/epoch - 671us/step
# Epoch 85/100
# 3390/3390 - 2s - loss: 0.2445 - accuracy: 0.8866 - 2s/epoch - 663us/step
# Epoch 86/100
# 3390/3390 - 2s - loss: 0.2427 - accuracy: 0.8885 - 2s/epoch - 697us/step
# Epoch 87/100
# 3390/3390 - 2s - loss: 0.2425 - accuracy: 0.8873 - 2s/epoch - 668us/step
# Epoch 88/100
# 3390/3390 - 2s - loss: 0.2412 - accuracy: 0.8893 - 2s/epoch - 664us/step
# Epoch 89/100
# 3390/3390 - 2s - loss: 0.2405 - accuracy: 0.8891 - 2s/epoch - 703us/step
# Epoch 90/100
# 3390/3390 - 2s - loss: 0.2391 - accuracy: 0.8894 - 2s/epoch - 699us/step
# Epoch 91/100
# 3390/3390 - 2s - loss: 0.2394 - accuracy: 0.8894 - 2s/epoch - 683us/step
# Epoch 92/100
# 3390/3390 - 2s - loss: 0.2376 - accuracy: 0.8899 - 2s/epoch - 681us/step
# Epoch 93/100
# 3390/3390 - 2s - loss: 0.2367 - accuracy: 0.8909 - 2s/epoch - 682us/step
# Epoch 94/100
# 3390/3390 - 2s - loss: 0.2368 - accuracy: 0.8914 - 2s/epoch - 672us/step
# Epoch 95/100
# 3390/3390 - 2s - loss: 0.2352 - accuracy: 0.8908 - 2s/epoch - 672us/step
# Epoch 96/100
# 3390/3390 - 2s - loss: 0.2342 - accuracy: 0.8929 - 2s/epoch - 683us/step
# Epoch 97/100
# 3390/3390 - 2s - loss: 0.2339 - accuracy: 0.8923 - 2s/epoch - 697us/step
# Epoch 98/100
# 3390/3390 - 2s - loss: 0.2330 - accuracy: 0.8920 - 2s/epoch - 712us/step
# Epoch 99/100
# 3390/3390 - 2s - loss: 0.2315 - accuracy: 0.8933 - 2s/epoch - 718us/step
# Epoch 100/100
# 3390/3390 - 2s - loss: 0.2309 - accuracy: 0.8942 - 2s/epoch - 709us/step

# %% [markdown]
# ## Evaluation of model

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1453/1453 - 1s - loss: 1.1926 - accuracy: 0.7261 - 849ms/epoch - 584us/step
# Normal Neural Network - Loss: 1.1925851106643677, Accuracy: 0.7261402606964111

# %%
encoded_predictions = model.predict(X_test_scaled)
prediction_labels_num = np.argmax(encoded_predictions, axis=1)

# %%
prediction_labels = [str(x) for x in prediction_labels_num]
for x in range(len(prediction_labels)):
    if prediction_labels[x] == '0':
        prediction_labels[x] = 'Popular'
    else:
        prediction_labels[x] = 'Unpopular'

# %%
results = confusion_matrix(y_test, prediction_labels) 
print('Confusion Matrix:')
print(results) 
print('Accuracy Score:', accuracy_score(y_test, prediction_labels))
print('Report:')
print(classification_report(y_test, prediction_labels))
# Out:
# Confusion Matrix:
# [[13848  6598]
#  [ 6131 19903]]
# Accuracy Score: 0.7261402753872633
# Report:
#               precision    recall  f1-score   support
#
#      Popular       0.69      0.68      0.69     20446
#    Unpopular       0.75      0.76      0.76     26034
#
#     accuracy                           0.73     46480
#    macro avg       0.72      0.72      0.72     46480
# weighted avg       0.73      0.73      0.73     46480
